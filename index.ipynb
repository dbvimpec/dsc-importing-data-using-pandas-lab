# %% [markdown]
# # Importing Data Using Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll get some practice with loading files with summary or metadata, and if you find that easy, the optional "level up" content covers loading data from a corrupted csv file.
#
# ## Objectives
# You will be able to:
#
# - Use pandas to import data from a CSV and and an Excel spreadsheet
#
# ##  Loading Files with Summary or Meta Data
#
# Load either of the files `'Zipcode_Demos.csv'` or `'Zipcode_Demos.xlsx'`. What's going on with this dataset? Clean it up into a useable format and describe the nuances of how the data is currently formatted.
#
# All data files are stored in a folder titled `'Data'`.

# %%
# !git clone https://github.com/dbvimpec/dsc-importing-data-using-pandas-lab
# Out:
# Cloning into 'dsc-importing-data-using-pandas-lab'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 248 (delta 154), reused 243 (delta 153), pack-reused 0 (from 0)
# Receiving objects: 100% (248/248), 1.83 MiB | 8.28 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# Import pandas using the standard alias
import pandas as pd

# %%
# Import the file and print the first 5 rows
df = pd.read_csv('/content/dsc-importing-data-using-pandas-lab/Data/Zipcode_Demos.csv')
df.head()
# Out:
#    0  Average Statistics Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  1                 NaN          0        NaN        NaN        NaN
# 1  2   JURISDICTION NAME    10005.8        NaN        NaN        NaN
# 2  3  COUNT PARTICIPANTS        9.4        NaN        NaN        NaN
# 3  4        COUNT FEMALE        4.8        NaN        NaN        NaN
# 4  5      PERCENT FEMALE      0.404        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 37 Unnamed: 38  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 4        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
#   Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# ...

# %%
# Print the last 5 rows of df
df.tail()
# Out:
#      0 Average Statistics Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 52  53              10006          6          2       0.33          4
# 53  54              10007          1          0          0          1
# 54  55              10009          2          0          0          2
# 55  56              10010          0          0          0          0
# 56  57              10011          3          2       0.67          1
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 37 Unnamed: 38  \
# 52       0.67          0          0          6  ...           6         100
# 53          1          0          0          1  ...           1         100
# 54          1          0          0          2  ...           2         100
# 55          0          0          0          0  ...           0           0
# 56       0.33          0          0          3  ...           3         100
#
#    Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# ...

# %%
# What is going on with this data set? Anything unusual?
df.info()

# Comment: Dataframe is really two table views, one on top of the other.
# The first is a summary view of the raw data below.
# There is also a blank row at row 1 in the file.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 47 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   0                   57 non-null     int64
#  1   Average Statistics  56 non-null     object
#  2   Unnamed: 2          57 non-null     object
#  3   Unnamed: 3          11 non-null     object
#  4   Unnamed: 4          11 non-null     object
#  5   Unnamed: 5          11 non-null     object
#  6   Unnamed: 6          11 non-null     object
#  7   Unnamed: 7          11 non-null     object
#  8   Unnamed: 8          11 non-null     object
#  9   Unnamed: 9          11 non-null     object
#  10  Unnamed: 10         11 non-null     object
#  11  Unnamed: 11         11 non-null     object
#  12  Unnamed: 12         11 non-null     object
#  13  Unnamed: 13         11 non-null     object
#  14  Unnamed: 14         11 non-null     object
# ...

# %%
# Clean up the dataset

prev_count = 10**3
for row in df.index:
    count = 0
    for entry in df.iloc[row].isnull():
        if entry:
            count += 1
    if count != prev_count and row!=0:
        print(f'On row {row} there are {count} null values. The previous row had {prev_count} null values.')
    prev_count = count
# Out:
# On row 1 there are 44 null values. The previous row had 45 null values.
# On row 46 there are 0 null values. The previous row had 44 null values.

# %% [markdown]
# ## Level Up (Optional) - Loading Corrupt CSV files
#
# Occasionally, you encounter some really ill-formatted data. One example of this can be data that has strings containing commas in a csv file. Under the standard protocol, when this occurs, one is supposed to use quotes to differentiate between the commas denoting fields and the commas within those fields themselves. For example, we could have a table like this:
#
# `ReviewerID,Rating,N_reviews,Review,VenueID
# 123456,4,137,This restaurant was pretty good, we had a great time.,98765`
#
# Which should be saved like this if it were a csv (to avoid confusion with the commas in the Review text):
# `"ReviewerID","Rating","N_reviews","Review","VenueID"
# "123456","4","137","This restaurant was pretty good, we had a great time.","98765"`
#
# Attempt to import the corrupt file, or at least a small preview of it. It is appropriately titled `'Yelp_Reviews_Corrupt.csv'`. Investigate some of the intricacies of skipping rows to then pass over this error and comment on what you think is going on.

# %%
# Hint: Here's a useful programming pattern to use
# Your code here
try:
    df = pd.read_csv('/content/dsc-importing-data-using-pandas-lab/Data/Yelp_Reviews_Corrupt.csv')
except Exception as e:
    print(e)
# Out:
# Error tokenizing data. C error: Expected 10 fields in line 2331, saw 11

# %%
# # Iteration 1
for i in range(1500,2000):
    try:
        df = pd.read_csv('/content/dsc-importing-data-using-pandas-lab/Data/Yelp_Reviews_Corrupt.csv', nrows=i)
    except:
        print(f'First failure at: {i}')
        break
df1 = pd.read_csv('/content/dsc-importing-data-using-pandas-lab/Data/Yelp_Reviews_Corrupt.csv', nrows=i-1)
print(len(df))
df1.head()
# Out:
# First failure at: 1962
# 1961
#   Unnamed: 0             business_id cool        date  funny  \
# 0          1  pomGBqfbxcqPv14c3XH-ZQ    0  2012-11-13    0.0
# 1          2  jtQARsP6P-LbkyjbO1qNGg    1  2014-10-23    1.0
# 2          4  Ums3gaP2qM3W1XcA5r6SsQ    0  2014-09-05    0.0
# 3          5  vgfcTvK81oD4r50NMjU2Ag    0  2011-02-25    0.0
# 4         10  yFumR3CWzpfvTH2FCthvVw    0  2016-06-15    0.0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw    5.0
# 1  LZp4UX5zK3e-c5ZGSeo3kA    1.0
# 2  jsDu6QEJHbwP2Blom1PLCA    5.0
# 3  pfavA0hr3nyqO61oupj-lA    1.0
# 4  STiFMww2z31siPY7BWNC2g    5.0
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...     0.0
# 1  Terrible. Dry corn bread. Rib tips were all fa...     3.0
# 2  Delicious healthy food. The steak is amazing. ...     0.0
# 3  This place sucks. The customer service is horr...     2.0
# ...

# %%
df.tail()
# Out:
#                                        Unnamed: 0             business_id  \
# 1956                                         4993  u8C8pRvaHXg3PgDrsUHJHQ
# 1957                                         4998  -9nai28tnoylwViuJVrYEQ
# 1958    I had an awesome great time with friends.                     NaN
# 1959  I loved the tapas and the excellent paella.                     NaN
# 1960              I can't wait to come back soon.                       0
#
#                         cool        date  funny               review_id  \
# 1956                       0  2016-08-08    0.0  gXmHGBSBBz2-uHdvGf4lZQ
# 1957                       0  2015-03-22    0.0  u-zqCN_IXfypJIUzIVUuzw
# 1958                     NaN         NaN    NaN                     NaN
# 1959                     NaN         NaN    NaN                     NaN
# 1960  otDVyX37h61WEbqPLEjCmQ         NaN    NaN                     NaN
#
#       stars                                               text  useful  \
# ...

# %%
# # Iteration 2
for i in range(0,500):
    try:
        temp = pd.read_csv('/content/dsc-importing-data-using-pandas-lab/Data/Yelp_Reviews_Corrupt.csv', skiprows=1962, nrows=i, names=df1.columns)
    except:
        print(f'First failure at: {i}')
        break
df2 = pd.read_csv('/content/dsc-importing-data-using-pandas-lab/Data/Yelp_Reviews_Corrupt.csv', skiprows=1962, nrows=i-1, names=df1.columns)
print(len(df2))
df2.head()
# Out:
# First failure at: 341
# 340
#                         Unnamed: 0             business_id  \
# 0  STAY AWAY FROM THIS PLACE!!!!!!                       5
# 1                             3948  GAKFx4jFUtTOTpp_jDJnuA
# 2                             3949  0QzCeORfF8EY34UODWRV9A
# 3                             3950  tlt8zNrZ6_A3DmXiM-cnBA
# 4                             3952  XD0LjNuPPwJPsTAHecUh7A
#
#                      cool        date  funny               review_id  stars  \
# 0  sDofYImMQQmu4Le5G9zmpQ         NaN    NaN                     NaN    NaN
# 1                       0  2017-09-01    0.0  OUZWMw7EgO7D596pUelSlA    5.0
# 2                       0  2017-09-03    0.0  7lbykaWFD8YBwT0mU1Rexw    4.0
# 3                       0  2016-06-12    0.0  Nd_soHwCYi8adcNIT2w9LQ    1.0
# 4                       0  2015-08-23    0.0  FUUTAr5CECrkfRa9Y2-MSg    1.0
#
#                                                 text  useful  \
# ...

# %%
temp = pd.read_csv('dsc-importing-data-using-pandas-lab/Data/Yelp_Reviews_Corrupt.csv', names=df1.columns, skiprows=1)
print(len(temp))
temp.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-30-d212da99daa2> in <cell line: 1>()
# ----> 1 temp = pd.read_csv('dsc-importing-data-using-pandas-lab/Data/Yelp_Reviews_Corrupt.csv', names=df1.columns, skiprows=1)
#       2 print(len(temp))
#       3 temp.head()
#
# ...

# %%
pd.read_csv('/content/dsc-importing-data-using-pandas-lab/Data/Yelp_Reviews_Corrupt.csv', skiprows=len(df1)+len(df2), names=df1.columns)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-32-736e0d384e87> in <cell line: 1>()
# ----> 1 pd.read_csv('/content/dsc-importing-data-using-pandas-lab/Data/Yelp_Reviews_Corrupt.csv', skiprows=len(df1)+len(df2), names=df1.columns)
#
# ...

# %% [markdown]
# ## Summary
#
# Congratulations, you now practiced your Pandas-importing skills.
